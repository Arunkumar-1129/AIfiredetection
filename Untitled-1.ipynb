# %%
print("Naaanthaa")
# Out:
# Naaanthaa

# %%
name=input("enter your name:").strip().title()
print(f"hello {name}")
# Out:
# hello Dfghj Werdtfygh Dergthyjk

# %%
# %pip install cowsay
import cowsay 
cowsay.trex("hello there !!🩵🩵🩵")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
#   _________________
# | hello there !!🩵🩵🩵 |
# ...
#                         \
#                          \
#                           \
#                            \
#                               .-=-==--==--.
#                         ..-=="  ,'o`)      `.
#                       ,'         `"'         \
#                      :  (                     `.__...._
#                      |                  )    /         `-=-.
#                      :       ,vv.-._   /    /               `---==-._
#                       \/\/\/VV ^ d88`;'    /                         `.
#                           ``  ^/d88P!'    /             ,              `._
#                              ^/    !'   ,.      ,      /                  "-,,__,,--'""""-.
#                             ^/    !'  ,'  \ . .(      (         _           )  ) ) ) ))_,-.\
# ...

# %%
# %pip install gTTS
from gtts import gTTS
text="hiii naanthaaa arun kumar undra per enna"
tts=gTTS(text=text,lang='en')
tts.save("naanthaa.mp3")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
name=input("enter the name and some data")
file=open('team.txt','a')
file.write(f"{name}")
file.close()

# %%
import random
names=random.randint(1,1000)
print(names)
# Out:
# 611
